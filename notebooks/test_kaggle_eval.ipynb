# %%
import sys
import pandas as pd
sys.path.append('../')
sys.path.append('../hms_pipeline')
from hms_pipeline.kaggle_kl_div import score, eval_subm

# %%
val_df_path = "/home/maxc/workspace/kaggle-hms/folds/val_fold_0.csv"
val_df = pd.read_csv(val_df_path)
val_df.head()

gt_df = pd.read_csv("/home/maxc/workspace/kaggle-hms/folds/all_targets.csv")
gt_df.head()
# Out:
#        eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0  1628180742           0                       0.0          353733
# 1  1628180742           1                       6.0          353733
# 2  1628180742           2                       8.0          353733
# 3  1628180742           3                      18.0          353733
# 4  1628180742           4                      24.0          353733
#
#    spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# 0                   0                               0.0   127492639
# 1                   1                               6.0  3887563113
# 2                   2                               8.0  1142670488
# 3                   3                              18.0  2718991173
# 4                   4                              24.0  3080632009
#
#    patient_id expert_consensus  seizure_vote  lpd_vote  gpd_vote  lrda_vote  \
# ...

# %%
print(val_df.shape)
# Out:
# (22104, 19)

# %%
val_df = val_df.groupby('unique_label').agg('first').reset_index()
val_df.head()
print(val_df.shape)
# Out:
# (4138, 19)

# %%
avg_subm = val_df.copy()
TARGETS = ['seizure_vote', 'lpd_vote', 'gpd_vote', 'lrda_vote', 'grda_vote', 'other_vote']

avg_subm[TARGETS] = 1/6

# %%
eval_subm(subm_df=avg_subm, gt_df=gt_df)
# Out:
# (106800, 7) (4138, 7) (4138, 7)
# 1.418312145680212

# %%
# shuffle val_df
val_df = avg_subm.sample(frac=1)
# print(gt_df.head())
gt_df.head()
# Out:
#        eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0  1628180742           0                       0.0          353733
# 1  1628180742           1                       6.0          353733
# 2  1628180742           2                       8.0          353733
# 3  1628180742           3                      18.0          353733
# 4  1628180742           4                      24.0          353733
#
#    spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# 0                   0                               0.0   127492639
# 1                   1                               6.0  3887563113
# 2                   2                               8.0  1142670488
# 3                   3                              18.0  2718991173
# 4                   4                              24.0  3080632009
#
#    patient_id expert_consensus  seizure_vote  lpd_vote  gpd_vote  lrda_vote  \
# ...

# %%
eval_subm(subm_df=val_df, gt_df = gt_df)
# Out:
# (106800, 7) (4138, 7) (4138, 7)
# 1.418312145680212
